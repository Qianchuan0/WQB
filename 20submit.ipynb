# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

"""
Alpha 提交脚本

本脚本基于 machine_lib.py, config.py, 和 succeselfcon.ipynb 作为蓝本编写。

功能：
1. 读取 'unsubmitted_alphas_list.csv' 文件。
2. 根据 'sharpe' 列从低到高排序。
3. 依次提交 '未提交alpha_id' 列中的 Alpha。
4. 成功提交 7 个 Alpha 后自动停止。
5. 使用 'machine_lib.py' 中的 login() 函数进行认证。
"""

import os
import pandas as pd
import requests
import time
import logging

# --- 蓝本模块导入 ---
# 尝试从蓝本文件中导入必要的函数和变量
try:
    from machine_lib import login
    
except ImportError as e:
    print(f"错误：无法导入蓝本模块: {e}")
    print("请确保此脚本 (submit_alphas.py) 与 machine_lib.py 和 config.py 位于同一目录中。")
    exit(1)
# --- 蓝本模块导入结束 ---


# --- 全局配置 ---

# 根据 succeselfcon.ipynb 构建CSV文件路径
RECORDS_PATH = r"D:\python\selfcor\records";
# *** 注意：已确认使用您修改后的文件 ***
# 源文件路径
CSV_FILE_PATH = os.path.join(RECORDS_PATH, "check_results.csv")

# 提交的 Alpha ID 所在的列名
ALPHA_ID_COLUMN = "未提交alpha_id"

# 排序依据的列名
SORT_BY_COLUMN = "sharpe"

# 提交API端点 (根据您的指定)
SUBMIT_URL_TEMPLATE = "https://api.worldquantbrain.com/alphas/{alpha_id}/submit"

# 每次提交之间的基础延迟（秒），避免过于频繁的请求
BASE_SUBMIT_DELAY_SEC = 2

# 配置日志
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)


def submit_alpha(session, alpha_id):
    """
    使用认证会话提交单个 Alpha。
    
    *** 已修改：新的重试逻辑 ***
    1. 持续重试 20 秒。
    2. 如果 20 秒内所有尝试（包括API速率限制等待）都未成功，则跳过。

    :param session: 已认证的 requests.Session 对象
    :param alpha_id: 要提交的 Alpha ID
    :return: True (如果成功) / False (如果最终失败)
    """
    submit_url = SUBMIT_URL_TEMPLATE.format(alpha_id=alpha_id)
    logger.info(f"  -> 准备 POST 到: {submit_url}")

    # --- 新的重试配置 (根据要求修改) ---
    TOTAL_TIMEOUT_SEC = 20      # *** 修改点：总超时改为 20 秒 ***
    RETRY_POLL_DELAY_SEC = 5    # 瞬时失败后，重试前的等待时间
    # --- 结束修改 ---

    # --- 内部辅助函数，执行单次尝试 ---
    def attempt_submit():
        """
        执行一次提交尝试。
        返回:
        - "SUCCESS": 2xx 成功
        - "PERMANENT_FAIL": 404, 409 (永久失败，不应重试)
        - "RATE_LIMIT": 收到 Retry-After 头部 (返回等待秒数)
        - "TRANSIENT_FAIL": 403, 5xx, 网络错误 (可重试)
        """
        try:
            headers = {
                'Origin': 'https://platform.worldquantbrain.com',
                'Referer': 'https://platform.worldquantbrain.com/', # 匹配您浏览器中的 Referer
                'accept': 'application/json;version=2.0', # 必须添加这个
                'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/141.0.0.0 Safari/537.36 Edg/141.0.0.0' # 最好也加上
            }
            # *** 修改点：单次请求超时改为 15 秒 (必须小于 TOTAL_TIMEOUT_SEC) ***
            response = session.post(submit_url, headers=headers, timeout=15)

            # 1. 检查 API 速率限制 (Retry-After)
            if "retry-after" in response.headers:
                try:
                    retry_seconds = float(response.headers["Retry-After"]) + 1 # 增加1秒缓冲
                except ValueError:
                    logger.warning("  -> 收到无效的 'Retry-After' 头部，使用默认延迟。")
                    retry_seconds = RETRY_POLL_DELAY_SEC
                logger.warning(f"  -> 收到 API 速率限制。等待 {retry_seconds:.1f} 秒后重试...")
                return "RATE_LIMIT", retry_seconds

            # 2. 检查成功
            if response.status_code in [200, 201, 202]:
                logger.info(f"  -> 成功提交！状态码: {response.status_code}")
                return "SUCCESS", None

            # 3. 检查已知的永久错误
            elif response.status_code == 409: # 409 Conflict
                logger.warning(f"  -> 提交失败 (状态码 409 Conflict)。永久失败：Alpha 已被提交或不符合资格。")
                return "PERMANENT_FAIL", None
            elif response.status_code == 404: # 404 Not Found
                logger.error(f"  -> 提交失败 (状态码 404 Not Found)。永久失败：Alpha ID '{alpha_id}' 不存在。")
                return "PERMANENT_FAIL", None
            
            # 4. 检查其他瞬时错误 (包括 403 Forbidden)
            elif response.status_code == 403:
                logger.error(f"  -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)")
                return "TRANSIENT_FAIL", None
            else:
                logger.error(f"  -> 提交失败。状态码: {response.status_code}。响应: {response.text[:200]}... (将重试)")
                return "TRANSIENT_FAIL", None

        except requests.exceptions.Timeout:
            logger.error(f"  -> 提交时发生请求超时 (超过 {15} 秒)。(将重试)")
            return "TRANSIENT_FAIL", None
        except requests.exceptions.RequestException as e:
            logger.error(f"  -> 提交时发生网络或请求错误: {e}。(将重试)")
            return "TRANSIENT_FAIL", None
        except Exception as e:
            # 捕获其他意外错误
            logger.error(f"  -> 提交时发生意外错误: {e}。(将重试)")
            return "TRANSIENT_FAIL", None

    # --- 新的重试逻辑 (20 秒超时) ---
    logger.info(f"  -> Alpha {alpha_id}: 开始 {TOTAL_TIMEOUT_SEC} 秒提交窗口...")
    start_time = time.time()
    
    while (time.time() - start_time) < TOTAL_TIMEOUT_SEC:
        status, data = attempt_submit()
        
        if status == "SUCCESS": 
            return True
        if status == "PERMANENT_FAIL": 
            return False

        # 确定等待时间
        wait_time = 0
        if status == "RATE_LIMIT":
            try:
                wait_time = float(data)
            except (ValueError, TypeError):
                logger.warning(f"  -> 收到无效的 'Retry-After' 值: {data}。使用默认值 {RETRY_POLL_DELAY_SEC} 秒。")
                wait_time = RETRY_POLL_DELAY_SEC
        elif status == "TRANSIENT_FAIL":
            wait_time = RETRY_POLL_DELAY_SEC
        
        # 检查等待是否会超出总超时时间
        # (time.time() + wait_time) 是预期的结束时间
        # (start_time + TOTAL_TIMEOUT_SEC) 是绝对的截止时间
        if (time.time() + wait_time) > (start_time + TOTAL_TIMEOUT_SEC):
            logger.warning(f"  -> Alpha {alpha_id}: 下次重试 (等待 {wait_time:.1f} 秒) 将超出 {TOTAL_TIMEOUT_SEC} 秒的总时限。")
            break # 超时，退出重试循环

        if wait_time > 0:
            # 确保睡眠时间不会超过剩余时间
            remaining_time = (start_time + TOTAL_TIMEOUT_SEC) - time.time()
            if wait_time > remaining_time:
                break # 等待时间超过总时限，直接跳出
            time.sleep(wait_time)

    # --- 最终失败 ---
    logger.error(f"  -> Alpha {alpha_id} 在 {TOTAL_TIMEOUT_SEC} 秒重试后最终失败。跳过此 Alpha。")
    return False

def main():
    """
    主执行函数
    """
    logger.info("--- Alpha 提交脚本启动 ---")
    
    # *** 新增：定义提交数量限制 ***
    SUBMISSION_LIMIT = 9
    
    # 步骤 1: 登录
    logger.info("正在登录 WorldQuant BRAIN (调用 machine_lib.py)...")
    try:
        session = login() #
        if not isinstance(session, requests.Session):
            logger.critical("登录失败，未返回有效的 Session 对象。脚本终止。")
            return
    except Exception as e:
        logger.critical(f"登录时发生致命错误: {e}。脚本终止。")
        return
    
    logger.info("登录成功。")

    # 步骤 2: 读取结果文件
    logger.info(f"正在读取结果文件: {CSV_FILE_PATH}")
    if not os.path.exists(CSV_FILE_PATH):
        logger.critical(f"错误：找不到文件 {CSV_FILE_PATH}。")
        # *** 修改：更新提示信息 ***
        logger.critical("请先运行[那个生成列表的脚本] 生成 unsubmitted_alphas_list.csv 文件。脚本终止。")
        return
        
    try:
        df = pd.read_csv(CSV_FILE_PATH,encoding='utf-8')
        
        # 验证必要的列是否存在
        if ALPHA_ID_COLUMN not in df.columns or SORT_BY_COLUMN not in df.columns:
            logger.critical(f"文件 {CSV_FILE_PATH} 缺少 '{ALPHA_ID_COLUMN}' 或 '{SORT_BY_COLUMN}' 列。脚本终止。")
            return
            
    except Exception as e:
        logger.critical(f"读取或解析 CSV 文件时出错: {e}。脚本终止。")
        return

    # 步骤 3: 按 Sharpe 排序 (从低到高)
    logger.info(f"正在根据 '{SORT_BY_COLUMN}' 列（升序）进行排序...")
    df_sorted = df.sort_values(by=SORT_BY_COLUMN, ascending=True)
    
    alpha_list_to_submit = df_sorted[[ALPHA_ID_COLUMN, SORT_BY_COLUMN]].dropna()
    total_count = len(alpha_list_to_submit)
    
    logger.info(f"文件加载并排序完毕。共找到 {total_count} 个有效的 Alpha 准备提交。")
    if total_count == 0:
        logger.warning("没有找到可提交的 Alpha。脚本执行完毕。")
        return

    # *** 新增：成功提交计数器 ***
    success_count = 0
    
    # 步骤 4: 遍历并提交
    for i, row in enumerate(alpha_list_to_submit.itertuples(), 1):
        alpha_id = row._asdict()[ALPHA_ID_COLUMN]
        sharpe_value = row._asdict()[SORT_BY_COLUMN]
        
        # *** 修改：更新日志以显示计数器 ***
        logger.info(f"\n--- (已成功 {success_count}/{SUBMISSION_LIMIT}) --- 正在处理第 {i}/{total_count} 个 Alpha ---")
        logger.info(f"Alpha ID: {alpha_id} (Sharpe: {sharpe_value:.4f})")
        
        try:
            success = submit_alpha(session, alpha_id)
            
            if success:
                logger.info(f"成功完成 Alpha {alpha_id} 的提交。")
                
                # *** 新增：更新计数器并检查限制 ***
                success_count += 1
                logger.info(f"--- 成功提交总数: {success_count}/{SUBMISSION_LIMIT} ---")
                
                if success_count >= SUBMISSION_LIMIT:
                    logger.info(f"已成功提交 {SUBMISSION_LIMIT} 个 Alpha，达到数量限制。停止脚本。")
                    break # 退出 for 循环
                # *** 修改结束 ***
                    
            else:
                logger.warning(f"Alpha {alpha_id} 提交失败或被跳过。")
                
            # 在两次提交之间添加礼貌性延迟
            logger.info(f"等待 {BASE_SUBMIT_DELAY_SEC} 秒后继续...")
            time.sleep(BASE_SUBMIT_DELAY_SEC)
            
        except KeyboardInterrupt:
            logger.warning("\n检测到用户中断 (Ctrl+C)。正在停止提交循环...")
            break
        except Exception as e:
            logger.error(f"处理 Alpha {alpha_id} 时发生严重错误: {e}")
            logger.info("等待 10 秒后尝试继续提交下一个 Alpha...")
            time.sleep(10)

    # *** 修改：更新最终的日志 ***
    logger.info(f"--- Alpha 提交脚本执行完毕 (共成功提交 {success_count} 个) ---")

if __name__ == "__main__":
    main()
# Out:
# 2025-10-28 21:39:51,217 - INFO - --- Alpha 提交脚本启动 ---
# 2025-10-28 21:39:51,219 - INFO - 正在登录 WorldQuant BRAIN (调用 machine_lib.py)...
# b'{"user":{"id":"ZY20347"},"token":{"expiry":14400.0},"permissions":["TUTORIAL","WORKDAY"]}'
# 2025-10-28 21:39:52,796 - INFO - 登录成功。
# 2025-10-28 21:39:52,797 - INFO - 正在读取结果文件: D:\python\selfcor\records\check_results.csv
# 2025-10-28 21:39:52,809 - INFO - 正在根据 'sharpe' 列（升序）进行排序...
# 2025-10-28 21:39:52,817 - INFO - 文件加载并排序完毕。共找到 68 个有效的 Alpha 准备提交。
# 2025-10-28 21:39:52,820 - INFO -
# --- (已成功 0/9) --- 正在处理第 1/68 个 Alpha ---
# 2025-10-28 21:39:52,820 - INFO - Alpha ID: ak6ZA9G5 (Sharpe: 1.4500)
# 2025-10-28 21:39:52,821 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/ak6ZA9G5/submit
# 2025-10-28 21:39:52,821 - INFO -   -> Alpha ak6ZA9G5: 开始 20 秒提交窗口...
# 2025-10-28 21:39:53,384 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:39:56,596 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:40:01,909 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:40:07,213 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:40:12,516 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:40:12,517 - WARNING -   -> Alpha ak6ZA9G5: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:40:12,518 - ERROR -   -> Alpha ak6ZA9G5 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:40:12,518 - WARNING - Alpha ak6ZA9G5 提交失败或被跳过。
# 2025-10-28 21:40:12,519 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:40:14,519 - INFO -
# --- (已成功 0/9) --- 正在处理第 2/68 个 Alpha ---
# 2025-10-28 21:40:14,520 - INFO - Alpha ID: 6X7VwZ87 (Sharpe: 1.4700)
# 2025-10-28 21:40:14,521 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/6X7VwZ87/submit
# 2025-10-28 21:40:14,522 - INFO -   -> Alpha 6X7VwZ87: 开始 20 秒提交窗口...
# 2025-10-28 21:40:15,132 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:40:18,324 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:40:23,639 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:40:28,938 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:40:34,242 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:40:34,243 - WARNING -   -> Alpha 6X7VwZ87: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:40:34,245 - ERROR -   -> Alpha 6X7VwZ87 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:40:34,246 - WARNING - Alpha 6X7VwZ87 提交失败或被跳过。
# 2025-10-28 21:40:34,247 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:40:36,248 - INFO -
# --- (已成功 0/9) --- 正在处理第 3/68 个 Alpha ---
# 2025-10-28 21:40:36,250 - INFO - Alpha ID: d5pVdPRK (Sharpe: 1.4900)
# 2025-10-28 21:40:36,252 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/d5pVdPRK/submit
# 2025-10-28 21:40:36,253 - INFO -   -> Alpha d5pVdPRK: 开始 20 秒提交窗口...
# 2025-10-28 21:40:36,896 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:40:40,111 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:40:45,429 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:40:50,730 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:40:56,034 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:40:56,036 - WARNING -   -> Alpha d5pVdPRK: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:40:56,037 - ERROR -   -> Alpha d5pVdPRK 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:40:56,038 - WARNING - Alpha d5pVdPRK 提交失败或被跳过。
# 2025-10-28 21:40:56,039 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:40:58,041 - INFO -
# --- (已成功 0/9) --- 正在处理第 4/68 个 Alpha ---
# 2025-10-28 21:40:58,043 - INFO - Alpha ID: QPMkVkwr (Sharpe: 1.4900)
# 2025-10-28 21:40:58,045 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/QPMkVkwr/submit
# 2025-10-28 21:40:58,046 - INFO -   -> Alpha QPMkVkwr: 开始 20 秒提交窗口...
# 2025-10-28 21:40:58,598 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:41:01,887 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:41:07,201 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:41:12,521 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:41:17,836 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:41:17,838 - WARNING -   -> Alpha QPMkVkwr: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:41:17,839 - ERROR -   -> Alpha QPMkVkwr 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:41:17,840 - WARNING - Alpha QPMkVkwr 提交失败或被跳过。
# 2025-10-28 21:41:17,841 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:41:19,843 - INFO -
# --- (已成功 0/9) --- 正在处理第 5/68 个 Alpha ---
# 2025-10-28 21:41:19,845 - INFO - Alpha ID: rKYgozqJ (Sharpe: 1.4900)
# 2025-10-28 21:41:19,846 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/rKYgozqJ/submit
# 2025-10-28 21:41:19,848 - INFO -   -> Alpha rKYgozqJ: 开始 20 秒提交窗口...
# 2025-10-28 21:41:20,350 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:41:23,506 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:41:28,801 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:41:34,096 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:41:39,390 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:41:39,393 - WARNING -   -> Alpha rKYgozqJ: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:41:39,395 - ERROR -   -> Alpha rKYgozqJ 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:41:39,396 - WARNING - Alpha rKYgozqJ 提交失败或被跳过。
# 2025-10-28 21:41:39,397 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:41:41,398 - INFO -
# --- (已成功 0/9) --- 正在处理第 6/68 个 Alpha ---
# 2025-10-28 21:41:41,399 - INFO - Alpha ID: E517jN6K (Sharpe: 1.5000)
# 2025-10-28 21:41:41,400 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/E517jN6K/submit
# 2025-10-28 21:41:41,400 - INFO -   -> Alpha E517jN6K: 开始 20 秒提交窗口...
# 2025-10-28 21:41:41,873 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:41:45,075 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:41:50,392 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:41:55,689 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:42:01,011 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:42:01,013 - WARNING -   -> Alpha E517jN6K: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:42:01,015 - ERROR -   -> Alpha E517jN6K 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:42:01,016 - WARNING - Alpha E517jN6K 提交失败或被跳过。
# 2025-10-28 21:42:01,017 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:42:03,018 - INFO -
# --- (已成功 0/9) --- 正在处理第 7/68 个 Alpha ---
# 2025-10-28 21:42:03,020 - INFO - Alpha ID: wpqxn9ZQ (Sharpe: 1.5000)
# 2025-10-28 21:42:03,022 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/wpqxn9ZQ/submit
# 2025-10-28 21:42:03,023 - INFO -   -> Alpha wpqxn9ZQ: 开始 20 秒提交窗口...
# 2025-10-28 21:42:03,766 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:42:07,023 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:42:12,339 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:42:17,683 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:42:22,983 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:42:22,985 - WARNING -   -> Alpha wpqxn9ZQ: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:42:22,986 - ERROR -   -> Alpha wpqxn9ZQ 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:42:22,987 - WARNING - Alpha wpqxn9ZQ 提交失败或被跳过。
# 2025-10-28 21:42:22,987 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:42:24,989 - INFO -
# --- (已成功 0/9) --- 正在处理第 8/68 个 Alpha ---
# 2025-10-28 21:42:24,991 - INFO - Alpha ID: E51WqX89 (Sharpe: 1.5000)
# 2025-10-28 21:42:24,992 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/E51WqX89/submit
# 2025-10-28 21:42:24,993 - INFO -   -> Alpha E51WqX89: 开始 20 秒提交窗口...
# 2025-10-28 21:42:25,622 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:42:28,800 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:42:34,104 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:42:39,410 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:42:44,719 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:42:44,722 - WARNING -   -> Alpha E51WqX89: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:42:44,724 - ERROR -   -> Alpha E51WqX89 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:42:44,726 - WARNING - Alpha E51WqX89 提交失败或被跳过。
# 2025-10-28 21:42:44,727 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:42:46,728 - INFO -
# --- (已成功 0/9) --- 正在处理第 9/68 个 Alpha ---
# 2025-10-28 21:42:46,730 - INFO - Alpha ID: vR8MLZNb (Sharpe: 1.5000)
# 2025-10-28 21:42:46,731 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/vR8MLZNb/submit
# 2025-10-28 21:42:46,733 - INFO -   -> Alpha vR8MLZNb: 开始 20 秒提交窗口...
# 2025-10-28 21:42:47,324 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:42:50,486 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:42:56,695 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:43:02,000 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:43:02,002 - WARNING -   -> Alpha vR8MLZNb: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:43:02,004 - ERROR -   -> Alpha vR8MLZNb 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:43:02,005 - WARNING - Alpha vR8MLZNb 提交失败或被跳过。
# 2025-10-28 21:43:02,006 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:43:04,008 - INFO -
# --- (已成功 0/9) --- 正在处理第 10/68 个 Alpha ---
# 2025-10-28 21:43:04,010 - INFO - Alpha ID: XgGQWEjz (Sharpe: 1.5000)
# 2025-10-28 21:43:04,012 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/XgGQWEjz/submit
# 2025-10-28 21:43:04,014 - INFO -   -> Alpha XgGQWEjz: 开始 20 秒提交窗口...
# 2025-10-28 21:43:04,596 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:43:07,780 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:43:14,064 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:43:19,369 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:43:19,371 - WARNING -   -> Alpha XgGQWEjz: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:43:19,372 - ERROR -   -> Alpha XgGQWEjz 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:43:19,374 - WARNING - Alpha XgGQWEjz 提交失败或被跳过。
# 2025-10-28 21:43:19,376 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:43:21,378 - INFO -
# --- (已成功 0/9) --- 正在处理第 11/68 个 Alpha ---
# 2025-10-28 21:43:21,380 - INFO - Alpha ID: A19ZznGR (Sharpe: 1.5000)
# 2025-10-28 21:43:21,382 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/A19ZznGR/submit
# 2025-10-28 21:43:21,384 - INFO -   -> Alpha A19ZznGR: 开始 20 秒提交窗口...
# 2025-10-28 21:43:21,903 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:43:25,100 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:43:30,409 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:43:35,716 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:43:41,022 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:43:41,023 - WARNING -   -> Alpha A19ZznGR: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:43:41,024 - ERROR -   -> Alpha A19ZznGR 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:43:41,025 - WARNING - Alpha A19ZznGR 提交失败或被跳过。
# 2025-10-28 21:43:41,026 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:43:43,028 - INFO -
# --- (已成功 0/9) --- 正在处理第 12/68 个 Alpha ---
# 2025-10-28 21:43:43,030 - INFO - Alpha ID: xAq822vg (Sharpe: 1.5000)
# 2025-10-28 21:43:43,031 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/xAq822vg/submit
# 2025-10-28 21:43:43,032 - INFO -   -> Alpha xAq822vg: 开始 20 秒提交窗口...
# 2025-10-28 21:43:43,497 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:43:46,694 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:43:52,868 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:43:58,200 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:43:58,202 - WARNING -   -> Alpha xAq822vg: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:43:58,204 - ERROR -   -> Alpha xAq822vg 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:43:58,206 - WARNING - Alpha xAq822vg 提交失败或被跳过。
# 2025-10-28 21:43:58,207 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:44:00,210 - INFO -
# --- (已成功 0/9) --- 正在处理第 13/68 个 Alpha ---
# 2025-10-28 21:44:00,213 - INFO - Alpha ID: 88b9aW8l (Sharpe: 1.5200)
# 2025-10-28 21:44:00,215 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/88b9aW8l/submit
# 2025-10-28 21:44:00,216 - INFO -   -> Alpha 88b9aW8l: 开始 20 秒提交窗口...
# 2025-10-28 21:44:00,724 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:44:03,895 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:44:09,198 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:44:14,515 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:44:19,826 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:44:19,828 - WARNING -   -> Alpha 88b9aW8l: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:44:19,830 - ERROR -   -> Alpha 88b9aW8l 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:44:19,832 - WARNING - Alpha 88b9aW8l 提交失败或被跳过。
# 2025-10-28 21:44:19,834 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:44:21,835 - INFO -
# --- (已成功 0/9) --- 正在处理第 14/68 个 Alpha ---
# 2025-10-28 21:44:21,837 - INFO - Alpha ID: A19ZkY7l (Sharpe: 1.5200)
# 2025-10-28 21:44:21,839 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/A19ZkY7l/submit
# 2025-10-28 21:44:21,841 - INFO -   -> Alpha A19ZkY7l: 开始 20 秒提交窗口...
# 2025-10-28 21:44:22,304 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:44:25,572 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:44:30,867 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:44:36,164 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:44:41,475 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:44:41,477 - WARNING -   -> Alpha A19ZkY7l: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:44:41,479 - ERROR -   -> Alpha A19ZkY7l 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:44:41,482 - WARNING - Alpha A19ZkY7l 提交失败或被跳过。
# 2025-10-28 21:44:41,484 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:44:43,487 - INFO -
# --- (已成功 0/9) --- 正在处理第 15/68 个 Alpha ---
# 2025-10-28 21:44:43,489 - INFO - Alpha ID: zqZ6pd8R (Sharpe: 1.5200)
# 2025-10-28 21:44:43,491 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/zqZ6pd8R/submit
# 2025-10-28 21:44:43,493 - INFO -   -> Alpha zqZ6pd8R: 开始 20 秒提交窗口...
# 2025-10-28 21:44:44,071 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:44:47,312 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:44:52,641 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:44:57,951 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:45:03,284 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:45:03,286 - WARNING -   -> Alpha zqZ6pd8R: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:45:03,287 - ERROR -   -> Alpha zqZ6pd8R 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:45:03,287 - WARNING - Alpha zqZ6pd8R 提交失败或被跳过。
# 2025-10-28 21:45:03,288 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:45:05,290 - INFO -
# --- (已成功 0/9) --- 正在处理第 16/68 个 Alpha ---
# 2025-10-28 21:45:05,293 - INFO - Alpha ID: JjqEvL6W (Sharpe: 1.5200)
# 2025-10-28 21:45:05,295 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/JjqEvL6W/submit
# 2025-10-28 21:45:05,297 - INFO -   -> Alpha JjqEvL6W: 开始 20 秒提交窗口...
# 2025-10-28 21:45:05,826 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:45:09,087 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:45:15,271 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:45:20,574 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:45:20,575 - WARNING -   -> Alpha JjqEvL6W: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:45:20,576 - ERROR -   -> Alpha JjqEvL6W 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:45:20,578 - WARNING - Alpha JjqEvL6W 提交失败或被跳过。
# 2025-10-28 21:45:20,580 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:45:22,582 - INFO -
# --- (已成功 0/9) --- 正在处理第 17/68 个 Alpha ---
# 2025-10-28 21:45:22,584 - INFO - Alpha ID: mLp3GERX (Sharpe: 1.5300)
# 2025-10-28 21:45:22,586 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/mLp3GERX/submit
# 2025-10-28 21:45:22,588 - INFO -   -> Alpha mLp3GERX: 开始 20 秒提交窗口...
# 2025-10-28 21:45:23,128 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:45:26,301 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:45:31,617 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:45:36,930 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:45:42,232 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:45:42,234 - WARNING -   -> Alpha mLp3GERX: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:45:42,236 - ERROR -   -> Alpha mLp3GERX 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:45:42,237 - WARNING - Alpha mLp3GERX 提交失败或被跳过。
# 2025-10-28 21:45:42,239 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:45:44,240 - INFO -
# --- (已成功 0/9) --- 正在处理第 18/68 个 Alpha ---
# 2025-10-28 21:45:44,242 - INFO - Alpha ID: LLWa1nnn (Sharpe: 1.5300)
# 2025-10-28 21:45:44,244 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/LLWa1nnn/submit
# 2025-10-28 21:45:44,246 - INFO -   -> Alpha LLWa1nnn: 开始 20 秒提交窗口...
# 2025-10-28 21:45:44,742 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:45:47,928 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:45:53,257 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:45:58,558 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:46:03,865 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:46:03,866 - WARNING -   -> Alpha LLWa1nnn: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:46:03,868 - ERROR -   -> Alpha LLWa1nnn 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:46:03,869 - WARNING - Alpha LLWa1nnn 提交失败或被跳过。
# 2025-10-28 21:46:03,870 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:46:05,873 - INFO -
# --- (已成功 0/9) --- 正在处理第 19/68 个 Alpha ---
# 2025-10-28 21:46:05,876 - INFO - Alpha ID: 0mq37G56 (Sharpe: 1.5300)
# 2025-10-28 21:46:05,878 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/0mq37G56/submit
# 2025-10-28 21:46:05,881 - INFO -   -> Alpha 0mq37G56: 开始 20 秒提交窗口...
# 2025-10-28 21:46:06,683 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:46:09,861 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:46:15,161 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:46:20,471 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:46:25,786 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:46:25,788 - WARNING -   -> Alpha 0mq37G56: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:46:25,789 - ERROR -   -> Alpha 0mq37G56 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:46:25,790 - WARNING - Alpha 0mq37G56 提交失败或被跳过。
# 2025-10-28 21:46:25,792 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:46:27,797 - INFO -
# --- (已成功 0/9) --- 正在处理第 20/68 个 Alpha ---
# 2025-10-28 21:46:27,799 - INFO - Alpha ID: wpqxgrMx (Sharpe: 1.5300)
# 2025-10-28 21:46:27,800 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/wpqxgrMx/submit
# 2025-10-28 21:46:27,801 - INFO -   -> Alpha wpqxgrMx: 开始 20 秒提交窗口...
# 2025-10-28 21:46:28,256 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:46:31,545 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:46:36,857 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:46:42,158 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:46:47,489 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:46:47,491 - WARNING -   -> Alpha wpqxgrMx: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:46:47,492 - ERROR -   -> Alpha wpqxgrMx 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:46:47,494 - WARNING - Alpha wpqxgrMx 提交失败或被跳过。
# 2025-10-28 21:46:47,496 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:46:49,498 - INFO -
# --- (已成功 0/9) --- 正在处理第 21/68 个 Alpha ---
# 2025-10-28 21:46:49,500 - INFO - Alpha ID: mLpRrnw9 (Sharpe: 1.5300)
# 2025-10-28 21:46:49,502 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/mLpRrnw9/submit
# 2025-10-28 21:46:49,504 - INFO -   -> Alpha mLpRrnw9: 开始 20 秒提交窗口...
# 2025-10-28 21:46:50,063 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:46:53,343 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:46:58,665 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:47:03,969 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:47:09,274 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:47:09,276 - WARNING -   -> Alpha mLpRrnw9: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:47:09,279 - ERROR -   -> Alpha mLpRrnw9 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:47:09,280 - WARNING - Alpha mLpRrnw9 提交失败或被跳过。
# 2025-10-28 21:47:09,282 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:47:11,283 - INFO -
# --- (已成功 0/9) --- 正在处理第 22/68 个 Alpha ---
# 2025-10-28 21:47:11,285 - INFO - Alpha ID: kqdrnQrg (Sharpe: 1.5300)
# 2025-10-28 21:47:11,287 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/kqdrnQrg/submit
# 2025-10-28 21:47:11,290 - INFO -   -> Alpha kqdrnQrg: 开始 20 秒提交窗口...
# 2025-10-28 21:47:11,779 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:47:14,978 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:47:20,305 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:47:25,628 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:47:30,945 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:47:30,946 - WARNING -   -> Alpha kqdrnQrg: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:47:30,947 - ERROR -   -> Alpha kqdrnQrg 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:47:30,948 - WARNING - Alpha kqdrnQrg 提交失败或被跳过。
# 2025-10-28 21:47:30,949 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:47:32,950 - INFO -
# --- (已成功 0/9) --- 正在处理第 23/68 个 Alpha ---
# 2025-10-28 21:47:32,952 - INFO - Alpha ID: WjMQP8Zj (Sharpe: 1.5300)
# 2025-10-28 21:47:32,953 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/WjMQP8Zj/submit
# 2025-10-28 21:47:32,954 - INFO -   -> Alpha WjMQP8Zj: 开始 20 秒提交窗口...
# 2025-10-28 21:47:33,539 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:47:36,820 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:47:42,144 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:47:47,509 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:47:52,810 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:47:52,811 - WARNING -   -> Alpha WjMQP8Zj: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:47:52,813 - ERROR -   -> Alpha WjMQP8Zj 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:47:52,814 - WARNING - Alpha WjMQP8Zj 提交失败或被跳过。
# 2025-10-28 21:47:52,815 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:47:54,817 - INFO -
# --- (已成功 0/9) --- 正在处理第 24/68 个 Alpha ---
# 2025-10-28 21:47:54,819 - INFO - Alpha ID: RRMQV9ad (Sharpe: 1.5300)
# 2025-10-28 21:47:54,821 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/RRMQV9ad/submit
# 2025-10-28 21:47:54,822 - INFO -   -> Alpha RRMQV9ad: 开始 20 秒提交窗口...
# 2025-10-28 21:47:55,354 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:47:58,559 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:48:04,848 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:48:10,153 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:48:10,155 - WARNING -   -> Alpha RRMQV9ad: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:48:10,156 - ERROR -   -> Alpha RRMQV9ad 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:48:10,157 - WARNING - Alpha RRMQV9ad 提交失败或被跳过。
# 2025-10-28 21:48:10,158 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:48:12,160 - INFO -
# --- (已成功 0/9) --- 正在处理第 25/68 个 Alpha ---
# 2025-10-28 21:48:12,162 - INFO - Alpha ID: 2rMzdg75 (Sharpe: 1.5400)
# 2025-10-28 21:48:12,164 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/2rMzdg75/submit
# 2025-10-28 21:48:12,165 - INFO -   -> Alpha 2rMzdg75: 开始 20 秒提交窗口...
# 2025-10-28 21:48:12,621 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:48:15,916 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:48:21,294 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:48:26,602 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:48:31,903 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:48:31,905 - WARNING -   -> Alpha 2rMzdg75: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:48:31,907 - ERROR -   -> Alpha 2rMzdg75 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:48:31,909 - WARNING - Alpha 2rMzdg75 提交失败或被跳过。
# 2025-10-28 21:48:31,910 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:48:33,914 - INFO -
# --- (已成功 0/9) --- 正在处理第 26/68 个 Alpha ---
# 2025-10-28 21:48:33,916 - INFO - Alpha ID: vR8MdNKQ (Sharpe: 1.5400)
# 2025-10-28 21:48:33,920 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/vR8MdNKQ/submit
# 2025-10-28 21:48:33,922 - INFO -   -> Alpha vR8MdNKQ: 开始 20 秒提交窗口...
# 2025-10-28 21:48:34,433 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:48:37,629 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:48:42,930 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:48:48,237 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:48:53,583 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:48:53,585 - WARNING -   -> Alpha vR8MdNKQ: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:48:53,586 - ERROR -   -> Alpha vR8MdNKQ 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:48:53,587 - WARNING - Alpha vR8MdNKQ 提交失败或被跳过。
# 2025-10-28 21:48:53,588 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:48:55,590 - INFO -
# --- (已成功 0/9) --- 正在处理第 27/68 个 Alpha ---
# 2025-10-28 21:48:55,592 - INFO - Alpha ID: 1Yeb7eRW (Sharpe: 1.5500)
# 2025-10-28 21:48:55,594 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/1Yeb7eRW/submit
# 2025-10-28 21:48:55,596 - INFO -   -> Alpha 1Yeb7eRW: 开始 20 秒提交窗口...
# 2025-10-28 21:48:56,203 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:48:59,382 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:49:04,693 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:49:10,194 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:49:15,504 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:49:15,506 - WARNING -   -> Alpha 1Yeb7eRW: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:49:15,508 - ERROR -   -> Alpha 1Yeb7eRW 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:49:15,509 - WARNING - Alpha 1Yeb7eRW 提交失败或被跳过。
# 2025-10-28 21:49:15,510 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:49:17,512 - INFO -
# --- (已成功 0/9) --- 正在处理第 28/68 个 Alpha ---
# 2025-10-28 21:49:17,515 - INFO - Alpha ID: O0OY3mzq (Sharpe: 1.5500)
# 2025-10-28 21:49:17,517 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/O0OY3mzq/submit
# 2025-10-28 21:49:17,518 - INFO -   -> Alpha O0OY3mzq: 开始 20 秒提交窗口...
# 2025-10-28 21:49:18,012 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:49:21,280 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:49:26,589 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:49:31,901 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:49:37,219 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:49:37,221 - WARNING -   -> Alpha O0OY3mzq: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:49:37,223 - ERROR -   -> Alpha O0OY3mzq 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:49:37,225 - WARNING - Alpha O0OY3mzq 提交失败或被跳过。
# 2025-10-28 21:49:37,227 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:49:39,229 - INFO -
# --- (已成功 0/9) --- 正在处理第 29/68 个 Alpha ---
# 2025-10-28 21:49:39,231 - INFO - Alpha ID: vR8MmeVz (Sharpe: 1.5500)
# 2025-10-28 21:49:39,233 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/vR8MmeVz/submit
# 2025-10-28 21:49:39,234 - INFO -   -> Alpha vR8MmeVz: 开始 20 秒提交窗口...
# 2025-10-28 21:49:39,781 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:49:43,055 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:49:48,357 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:49:53,657 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:49:58,963 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:49:58,966 - WARNING -   -> Alpha vR8MmeVz: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:49:58,967 - ERROR -   -> Alpha vR8MmeVz 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:49:58,968 - WARNING - Alpha vR8MmeVz 提交失败或被跳过。
# 2025-10-28 21:49:58,969 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:50:00,970 - INFO -
# --- (已成功 0/9) --- 正在处理第 30/68 个 Alpha ---
# 2025-10-28 21:50:00,972 - INFO - Alpha ID: WjMQ9ovG (Sharpe: 1.5500)
# 2025-10-28 21:50:00,972 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/WjMQ9ovG/submit
# 2025-10-28 21:50:00,974 - INFO -   -> Alpha WjMQ9ovG: 开始 20 秒提交窗口...
# 2025-10-28 21:50:01,599 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:50:04,790 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:50:10,101 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:50:15,411 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:50:20,724 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:50:20,725 - WARNING -   -> Alpha WjMQ9ovG: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:50:20,727 - ERROR -   -> Alpha WjMQ9ovG 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:50:20,729 - WARNING - Alpha WjMQ9ovG 提交失败或被跳过。
# 2025-10-28 21:50:20,731 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:50:22,733 - INFO -
# --- (已成功 0/9) --- 正在处理第 31/68 个 Alpha ---
# 2025-10-28 21:50:22,737 - INFO - Alpha ID: KP3dk7Pz (Sharpe: 1.5500)
# 2025-10-28 21:50:22,739 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/KP3dk7Pz/submit
# 2025-10-28 21:50:22,742 - INFO -   -> Alpha KP3dk7Pz: 开始 20 秒提交窗口...
# 2025-10-28 21:50:23,242 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:50:26,521 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:50:32,687 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:50:38,963 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:50:38,964 - WARNING -   -> Alpha KP3dk7Pz: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:50:38,966 - ERROR -   -> Alpha KP3dk7Pz 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:50:38,967 - WARNING - Alpha KP3dk7Pz 提交失败或被跳过。
# 2025-10-28 21:50:38,968 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:50:40,970 - INFO -
# --- (已成功 0/9) --- 正在处理第 32/68 个 Alpha ---
# 2025-10-28 21:50:40,972 - INFO - Alpha ID: gJ6OxG10 (Sharpe: 1.5500)
# 2025-10-28 21:50:40,974 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/gJ6OxG10/submit
# 2025-10-28 21:50:40,975 - INFO -   -> Alpha gJ6OxG10: 开始 20 秒提交窗口...
# 2025-10-28 21:50:41,547 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:50:44,723 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:50:50,988 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:50:57,170 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:50:57,172 - WARNING -   -> Alpha gJ6OxG10: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:50:57,174 - ERROR -   -> Alpha gJ6OxG10 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:50:57,175 - WARNING - Alpha gJ6OxG10 提交失败或被跳过。
# 2025-10-28 21:50:57,177 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:50:59,179 - INFO -
# --- (已成功 0/9) --- 正在处理第 33/68 个 Alpha ---
# 2025-10-28 21:50:59,181 - INFO - Alpha ID: gJ6Oxq6K (Sharpe: 1.5600)
# 2025-10-28 21:50:59,183 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/gJ6Oxq6K/submit
# 2025-10-28 21:50:59,184 - INFO -   -> Alpha gJ6Oxq6K: 开始 20 秒提交窗口...
# 2025-10-28 21:50:59,720 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:51:02,889 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:51:09,075 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:51:14,392 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:51:14,394 - WARNING -   -> Alpha gJ6Oxq6K: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:51:14,396 - ERROR -   -> Alpha gJ6Oxq6K 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:51:14,398 - WARNING - Alpha gJ6Oxq6K 提交失败或被跳过。
# 2025-10-28 21:51:14,399 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:51:16,401 - INFO -
# --- (已成功 0/9) --- 正在处理第 34/68 个 Alpha ---
# 2025-10-28 21:51:16,405 - INFO - Alpha ID: XgGrd7Q8 (Sharpe: 1.5600)
# 2025-10-28 21:51:16,407 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/XgGrd7Q8/submit
# 2025-10-28 21:51:16,415 - INFO -   -> Alpha XgGrd7Q8: 开始 20 秒提交窗口...
# 2025-10-28 21:51:16,912 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:51:20,092 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:51:25,407 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:51:30,714 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:51:36,022 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:51:36,023 - WARNING -   -> Alpha XgGrd7Q8: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:51:36,025 - ERROR -   -> Alpha XgGrd7Q8 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:51:36,026 - WARNING - Alpha XgGrd7Q8 提交失败或被跳过。
# 2025-10-28 21:51:36,028 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:51:38,030 - INFO -
# --- (已成功 0/9) --- 正在处理第 35/68 个 Alpha ---
# 2025-10-28 21:51:38,033 - INFO - Alpha ID: QPMkeeZg (Sharpe: 1.5600)
# 2025-10-28 21:51:38,035 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/QPMkeeZg/submit
# 2025-10-28 21:51:38,037 - INFO -   -> Alpha QPMkeeZg: 开始 20 秒提交窗口...
# 2025-10-28 21:51:38,538 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:51:41,722 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:51:47,027 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:51:52,355 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:51:57,653 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:51:57,654 - WARNING -   -> Alpha QPMkeeZg: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:51:57,655 - ERROR -   -> Alpha QPMkeeZg 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:51:57,657 - WARNING - Alpha QPMkeeZg 提交失败或被跳过。
# 2025-10-28 21:51:57,659 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:51:59,662 - INFO -
# --- (已成功 0/9) --- 正在处理第 36/68 个 Alpha ---
# 2025-10-28 21:51:59,666 - INFO - Alpha ID: kqdr5Adl (Sharpe: 1.5600)
# 2025-10-28 21:51:59,668 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/kqdr5Adl/submit
# 2025-10-28 21:51:59,673 - INFO -   -> Alpha kqdr5Adl: 开始 20 秒提交窗口...
# 2025-10-28 21:52:00,129 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:52:03,307 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:52:08,680 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:52:13,999 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:52:19,307 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:52:19,308 - WARNING -   -> Alpha kqdr5Adl: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:52:19,309 - ERROR -   -> Alpha kqdr5Adl 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:52:19,311 - WARNING - Alpha kqdr5Adl 提交失败或被跳过。
# 2025-10-28 21:52:19,312 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:52:21,314 - INFO -
# --- (已成功 0/9) --- 正在处理第 37/68 个 Alpha ---
# 2025-10-28 21:52:21,315 - INFO - Alpha ID: E51WEXl1 (Sharpe: 1.5700)
# 2025-10-28 21:52:21,316 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/E51WEXl1/submit
# 2025-10-28 21:52:21,318 - INFO -   -> Alpha E51WEXl1: 开始 20 秒提交窗口...
# 2025-10-28 21:52:21,865 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:52:25,172 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:52:31,343 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:52:36,644 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:52:36,645 - WARNING -   -> Alpha E51WEXl1: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:52:36,646 - ERROR -   -> Alpha E51WEXl1 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:52:36,647 - WARNING - Alpha E51WEXl1 提交失败或被跳过。
# 2025-10-28 21:52:36,649 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:52:38,652 - INFO -
# --- (已成功 0/9) --- 正在处理第 38/68 个 Alpha ---
# 2025-10-28 21:52:38,654 - INFO - Alpha ID: d5pVqLW2 (Sharpe: 1.5700)
# 2025-10-28 21:52:38,656 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/d5pVqLW2/submit
# 2025-10-28 21:52:38,658 - INFO -   -> Alpha d5pVqLW2: 开始 20 秒提交窗口...
# 2025-10-28 21:52:39,104 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:52:42,366 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:52:47,672 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:52:52,967 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:52:58,266 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:52:58,268 - WARNING -   -> Alpha d5pVqLW2: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:52:58,269 - ERROR -   -> Alpha d5pVqLW2 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:52:58,270 - WARNING - Alpha d5pVqLW2 提交失败或被跳过。
# 2025-10-28 21:52:58,271 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:53:00,272 - INFO -
# --- (已成功 0/9) --- 正在处理第 39/68 个 Alpha ---
# 2025-10-28 21:53:00,273 - INFO - Alpha ID: xAq6EM7q (Sharpe: 1.5800)
# 2025-10-28 21:53:00,274 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/xAq6EM7q/submit
# 2025-10-28 21:53:00,274 - INFO -   -> Alpha xAq6EM7q: 开始 20 秒提交窗口...
# 2025-10-28 21:53:00,820 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:53:03,990 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:53:09,306 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:53:16,099 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:53:16,101 - WARNING -   -> Alpha xAq6EM7q: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:53:16,101 - ERROR -   -> Alpha xAq6EM7q 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:53:16,102 - WARNING - Alpha xAq6EM7q 提交失败或被跳过。
# 2025-10-28 21:53:16,105 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:53:18,113 - INFO -
# --- (已成功 0/9) --- 正在处理第 40/68 个 Alpha ---
# 2025-10-28 21:53:18,115 - INFO - Alpha ID: zqZ6RXPR (Sharpe: 1.5800)
# 2025-10-28 21:53:18,118 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/zqZ6RXPR/submit
# 2025-10-28 21:53:18,120 - INFO -   -> Alpha zqZ6RXPR: 开始 20 秒提交窗口...
# 2025-10-28 21:53:18,656 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:53:21,949 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:53:27,276 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:53:32,595 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:53:37,903 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:53:37,905 - WARNING -   -> Alpha zqZ6RXPR: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# ...
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:58:49,284 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:58:54,587 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:58:59,890 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:58:59,892 - WARNING -   -> Alpha zqZ6azQ1: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:58:59,893 - ERROR -   -> Alpha zqZ6azQ1 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:58:59,895 - WARNING - Alpha zqZ6azQ1 提交失败或被跳过。
# 2025-10-28 21:58:59,897 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:59:01,898 - INFO -
# --- (已成功 0/9) --- 正在处理第 56/68 个 Alpha ---
# 2025-10-28 21:59:01,901 - INFO - Alpha ID: N10w8JAq (Sharpe: 1.6400)
# 2025-10-28 21:59:01,902 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/N10w8JAq/submit
# 2025-10-28 21:59:01,904 - INFO -   -> Alpha N10w8JAq: 开始 20 秒提交窗口...
# 2025-10-28 21:59:02,391 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:59:05,648 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:59:10,943 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:59:16,249 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:59:21,552 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:59:21,554 - WARNING -   -> Alpha N10w8JAq: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:59:21,555 - ERROR -   -> Alpha N10w8JAq 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:59:21,555 - WARNING - Alpha N10w8JAq 提交失败或被跳过。
# 2025-10-28 21:59:21,556 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:59:23,557 - INFO -
# --- (已成功 0/9) --- 正在处理第 57/68 个 Alpha ---
# 2025-10-28 21:59:23,559 - INFO - Alpha ID: KP30Q29x (Sharpe: 1.6400)
# 2025-10-28 21:59:23,560 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/KP30Q29x/submit
# 2025-10-28 21:59:23,561 - INFO -   -> Alpha KP30Q29x: 开始 20 秒提交窗口...
# 2025-10-28 21:59:24,073 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:59:27,338 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:59:32,671 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:59:37,982 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:59:43,279 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:59:43,280 - WARNING -   -> Alpha KP30Q29x: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 21:59:43,280 - ERROR -   -> Alpha KP30Q29x 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 21:59:43,281 - WARNING - Alpha KP30Q29x 提交失败或被跳过。
# 2025-10-28 21:59:43,281 - INFO - 等待 2 秒后继续...
# 2025-10-28 21:59:45,282 - INFO -
# --- (已成功 0/9) --- 正在处理第 58/68 个 Alpha ---
# 2025-10-28 21:59:45,283 - INFO - Alpha ID: xAq6EM0J (Sharpe: 1.6500)
# 2025-10-28 21:59:45,284 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/xAq6EM0J/submit
# 2025-10-28 21:59:45,285 - INFO -   -> Alpha xAq6EM0J: 开始 20 秒提交窗口...
# 2025-10-28 21:59:45,729 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 21:59:48,937 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 21:59:54,236 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 21:59:59,554 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 22:00:04,850 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 22:00:04,852 - WARNING -   -> Alpha xAq6EM0J: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 22:00:04,852 - ERROR -   -> Alpha xAq6EM0J 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 22:00:04,853 - WARNING - Alpha xAq6EM0J 提交失败或被跳过。
# 2025-10-28 22:00:04,853 - INFO - 等待 2 秒后继续...
# 2025-10-28 22:00:06,854 - INFO -
# --- (已成功 0/9) --- 正在处理第 59/68 个 Alpha ---
# 2025-10-28 22:00:06,855 - INFO - Alpha ID: wpqxVR1x (Sharpe: 1.6500)
# 2025-10-28 22:00:06,856 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/wpqxVR1x/submit
# 2025-10-28 22:00:06,856 - INFO -   -> Alpha wpqxVR1x: 开始 20 秒提交窗口...
# 2025-10-28 22:00:07,380 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 22:00:10,701 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 22:00:16,011 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 22:00:21,318 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 22:00:26,662 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 22:00:26,663 - WARNING -   -> Alpha wpqxVR1x: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 22:00:26,664 - ERROR -   -> Alpha wpqxVR1x 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 22:00:26,664 - WARNING - Alpha wpqxVR1x 提交失败或被跳过。
# 2025-10-28 22:00:26,664 - INFO - 等待 2 秒后继续...
# 2025-10-28 22:00:28,665 - INFO -
# --- (已成功 0/9) --- 正在处理第 60/68 个 Alpha ---
# 2025-10-28 22:00:28,666 - INFO - Alpha ID: LLWaJva6 (Sharpe: 1.6500)
# 2025-10-28 22:00:28,667 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/LLWaJva6/submit
# 2025-10-28 22:00:28,668 - INFO -   -> Alpha LLWaJva6: 开始 20 秒提交窗口...
# 2025-10-28 22:00:29,237 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 22:00:32,549 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 22:00:38,879 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 22:00:44,185 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 22:00:44,185 - WARNING -   -> Alpha LLWaJva6: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 22:00:44,186 - ERROR -   -> Alpha LLWaJva6 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 22:00:44,187 - WARNING - Alpha LLWaJva6 提交失败或被跳过。
# 2025-10-28 22:00:44,187 - INFO - 等待 2 秒后继续...
# 2025-10-28 22:00:46,188 - INFO -
# --- (已成功 0/9) --- 正在处理第 61/68 个 Alpha ---
# 2025-10-28 22:00:46,189 - INFO - Alpha ID: E51723Mm (Sharpe: 1.6800)
# 2025-10-28 22:00:46,190 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/E51723Mm/submit
# 2025-10-28 22:00:46,192 - INFO -   -> Alpha E51723Mm: 开始 20 秒提交窗口...
# 2025-10-28 22:00:46,652 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 22:00:49,939 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 22:00:56,151 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 22:01:01,461 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 22:01:01,462 - WARNING -   -> Alpha E51723Mm: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 22:01:01,462 - ERROR -   -> Alpha E51723Mm 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 22:01:01,463 - WARNING - Alpha E51723Mm 提交失败或被跳过。
# 2025-10-28 22:01:01,463 - INFO - 等待 2 秒后继续...
# 2025-10-28 22:01:03,464 - INFO -
# --- (已成功 0/9) --- 正在处理第 62/68 个 Alpha ---
# 2025-10-28 22:01:03,466 - INFO - Alpha ID: QPMJgWo5 (Sharpe: 1.6800)
# 2025-10-28 22:01:03,466 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/QPMJgWo5/submit
# 2025-10-28 22:01:03,467 - INFO -   -> Alpha QPMJgWo5: 开始 20 秒提交窗口...
# 2025-10-28 22:01:04,070 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 22:01:07,282 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 22:01:12,609 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 22:01:17,902 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 22:01:23,213 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 22:01:23,215 - WARNING -   -> Alpha QPMJgWo5: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 22:01:23,216 - ERROR -   -> Alpha QPMJgWo5 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 22:01:23,217 - WARNING - Alpha QPMJgWo5 提交失败或被跳过。
# 2025-10-28 22:01:23,217 - INFO - 等待 2 秒后继续...
# 2025-10-28 22:01:25,219 - INFO -
# --- (已成功 0/9) --- 正在处理第 63/68 个 Alpha ---
# 2025-10-28 22:01:25,220 - INFO - Alpha ID: ak6YG3GR (Sharpe: 1.6800)
# 2025-10-28 22:01:25,221 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/ak6YG3GR/submit
# 2025-10-28 22:01:25,222 - INFO -   -> Alpha ak6YG3GR: 开始 20 秒提交窗口...
# 2025-10-28 22:01:26,066 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 22:01:29,361 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 22:01:34,666 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 22:01:40,088 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 22:01:45,391 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 22:01:45,392 - WARNING -   -> Alpha ak6YG3GR: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 22:01:45,393 - ERROR -   -> Alpha ak6YG3GR 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 22:01:45,394 - WARNING - Alpha ak6YG3GR 提交失败或被跳过。
# 2025-10-28 22:01:45,395 - INFO - 等待 2 秒后继续...
# 2025-10-28 22:01:47,396 - INFO -
# --- (已成功 0/9) --- 正在处理第 64/68 个 Alpha ---
# 2025-10-28 22:01:47,397 - INFO - Alpha ID: O0OYVZgb (Sharpe: 1.6800)
# 2025-10-28 22:01:47,398 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/O0OYVZgb/submit
# 2025-10-28 22:01:47,399 - INFO -   -> Alpha O0OYVZgb: 开始 20 秒提交窗口...
# 2025-10-28 22:01:48,055 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 22:01:51,448 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 22:01:56,745 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 22:02:02,038 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 22:02:07,348 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 22:02:07,349 - WARNING -   -> Alpha O0OYVZgb: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 22:02:07,350 - ERROR -   -> Alpha O0OYVZgb 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 22:02:07,351 - WARNING - Alpha O0OYVZgb 提交失败或被跳过。
# 2025-10-28 22:02:07,351 - INFO - 等待 2 秒后继续...
# 2025-10-28 22:02:09,352 - INFO -
# --- (已成功 0/9) --- 正在处理第 65/68 个 Alpha ---
# 2025-10-28 22:02:09,353 - INFO - Alpha ID: WjMQmZ0P (Sharpe: 1.6800)
# 2025-10-28 22:02:09,353 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/WjMQmZ0P/submit
# 2025-10-28 22:02:09,354 - INFO -   -> Alpha WjMQmZ0P: 开始 20 秒提交窗口...
# 2025-10-28 22:02:09,889 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 22:02:13,050 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 22:02:18,349 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 22:02:23,658 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 22:02:28,959 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 22:02:28,960 - WARNING -   -> Alpha WjMQmZ0P: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 22:02:28,960 - ERROR -   -> Alpha WjMQmZ0P 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 22:02:28,961 - WARNING - Alpha WjMQmZ0P 提交失败或被跳过。
# 2025-10-28 22:02:28,961 - INFO - 等待 2 秒后继续...
# 2025-10-28 22:02:30,962 - INFO -
# --- (已成功 0/9) --- 正在处理第 66/68 个 Alpha ---
# 2025-10-28 22:02:30,963 - INFO - Alpha ID: vR8Mkvwz (Sharpe: 1.6800)
# 2025-10-28 22:02:30,964 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/vR8Mkvwz/submit
# 2025-10-28 22:02:30,964 - INFO -   -> Alpha vR8Mkvwz: 开始 20 秒提交窗口...
# 2025-10-28 22:02:31,499 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 22:02:34,780 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 22:02:40,088 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 22:02:45,390 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 22:02:50,821 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 22:02:50,823 - WARNING -   -> Alpha vR8Mkvwz: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 22:02:50,825 - ERROR -   -> Alpha vR8Mkvwz 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 22:02:50,826 - WARNING - Alpha vR8Mkvwz 提交失败或被跳过。
# 2025-10-28 22:02:50,828 - INFO - 等待 2 秒后继续...
# 2025-10-28 22:02:52,831 - INFO -
# --- (已成功 0/9) --- 正在处理第 67/68 个 Alpha ---
# 2025-10-28 22:02:52,833 - INFO - Alpha ID: ZY65NOZd (Sharpe: 1.6900)
# 2025-10-28 22:02:52,835 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/ZY65NOZd/submit
# 2025-10-28 22:02:52,836 - INFO -   -> Alpha ZY65NOZd: 开始 20 秒提交窗口...
# 2025-10-28 22:02:53,336 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 22:02:56,623 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 22:03:01,928 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 22:03:07,235 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 22:03:12,610 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 22:03:12,612 - WARNING -   -> Alpha ZY65NOZd: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 22:03:12,613 - ERROR -   -> Alpha ZY65NOZd 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 22:03:12,615 - WARNING - Alpha ZY65NOZd 提交失败或被跳过。
# 2025-10-28 22:03:12,616 - INFO - 等待 2 秒后继续...
# 2025-10-28 22:03:14,621 - INFO -
# --- (已成功 0/9) --- 正在处理第 68/68 个 Alpha ---
# 2025-10-28 22:03:14,625 - INFO - Alpha ID: pwmXeVv3 (Sharpe: 1.7000)
# 2025-10-28 22:03:14,626 - INFO -   -> 准备 POST 到: https://api.worldquantbrain.com/alphas/pwmXeVv3/submit
# 2025-10-28 22:03:14,627 - INFO -   -> Alpha pwmXeVv3: 开始 20 秒提交窗口...
# 2025-10-28 22:03:15,197 - WARNING -   -> 收到 API 速率限制。等待 2.0 秒后重试...
# 2025-10-28 22:03:18,457 - ERROR -   -> 提交失败。状态码: 400。响应: <html>
# <head><title>400 The plain HTTP request was sent to HTTPS port</title></head>
# <body>
# <center><h1>400 Bad Request</h1></center>
# <center>The plain HTTP request was sent to HTTPS port</center>... (将重试)
# 2025-10-28 22:03:23,764 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 22:03:29,141 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 22:03:34,438 - ERROR -   -> 提交失败 (状态码 403 Forbidden)。权限不足或认证失败。(将重试)
# 2025-10-28 22:03:34,440 - WARNING -   -> Alpha pwmXeVv3: 下次重试 (等待 5.0 秒) 将超出 20 秒的总时限。
# 2025-10-28 22:03:34,442 - ERROR -   -> Alpha pwmXeVv3 在 20 秒重试后最终失败。跳过此 Alpha。
# 2025-10-28 22:03:34,443 - WARNING - Alpha pwmXeVv3 提交失败或被跳过。
# 2025-10-28 22:03:34,444 - INFO - 等待 2 秒后继续...
# 2025-10-28 22:03:36,448 - INFO - --- Alpha 提交脚本执行完毕 (共成功提交 0 个) ---
